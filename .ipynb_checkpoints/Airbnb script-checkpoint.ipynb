# %%
# import all the necessary libraries for the analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# read in all the datasets
listings = pd.read_csv('./listings.csv')
calendar = pd.read_csv('./calendar.csv.gz', compression='gzip')

# %%
calendar.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0       11943  2020-03-14         t  $150.00        $150.00               1
# 1        2060  2020-03-14         t  $100.00        $100.00               1
# 2        2060  2020-03-15         t  $100.00        $100.00               1
# 3        2060  2020-03-16         t  $100.00        $100.00               1
# 4        2060  2020-03-17         t  $100.00        $100.00               1
#
#    maximum_nights
# 0             730
# 1             730
# 2             730
# 3             730
# 4             730

# %%
listings.head()
# Out:
#      id                                       name  host_id    host_name  \
# 0  2060                                 Modern NYC     2259        Jenny
# 1  2595                      Skylit Midtown Castle     2845     Jennifer
# 2  3831            Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 3  5099  Large Cozy 1 BR Apartment In Midtown East     7322        Chris
# 4  5114                  Super Room in Great area.     7345      Yasmine
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0           Manhattan  Washington Heights  40.85722  -73.93790
# 1           Manhattan             Midtown  40.75362  -73.98377
# 2            Brooklyn        Clinton Hill  40.68514  -73.95976
# 3           Manhattan         Murray Hill  40.74767  -73.97500
# 4           Manhattan     Lower East Side  40.71910  -73.99040
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    100               1                  1  2008-09-22
# 1  Entire home/apt    225               7                 48  2019-11-04
# 2  Entire home/apt     89               1                313  2020-02-23
# 3  Entire home/apt    200               3                 78  2019-10-13
# 4     Private room     94               1                 75  2012-06-09
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.01                               1               365
# 1               0.38                               2               339
# 2               4.71                               1               151
# 3               0.59                               1                 0
# 4               0.56                               3               109

# %%
listings.shape
# Out:
# (50796, 16)

# %%
calendar.shape
# Out:
# (18540540, 7)

# %%
# rename the id in the listings dataframe to listing_id
listings.rename(columns ={'id': 'listing_id'}, inplace = True)

# merge listings and calendar
df = pd.merge(listings, calendar, on = 'listing_id')

# convert the available column to a binary column called booked
df['booked'] = np.where(df['available']=='f', 1, 0)

df.head()
# Out:
#    listing_id        name  host_id host_name neighbourhood_group  \
# 0        2060  Modern NYC     2259     Jenny           Manhattan
# 1        2060  Modern NYC     2259     Jenny           Manhattan
# 2        2060  Modern NYC     2259     Jenny           Manhattan
# 3        2060  Modern NYC     2259     Jenny           Manhattan
# 4        2060  Modern NYC     2259     Jenny           Manhattan
#
#         neighbourhood  latitude  longitude     room_type  price_x  ...  \
# 0  Washington Heights  40.85722   -73.9379  Private room      100  ...
# 1  Washington Heights  40.85722   -73.9379  Private room      100  ...
# 2  Washington Heights  40.85722   -73.9379  Private room      100  ...
# 3  Washington Heights  40.85722   -73.9379  Private room      100  ...
# 4  Washington Heights  40.85722   -73.9379  Private room      100  ...
#
#    reviews_per_month  calculated_host_listings_count availability_365  \
# 0               0.01                               1              365
# 1               0.01                               1              365
# 2               0.01                               1              365
# 3               0.01                               1              365
# 4               0.01                               1              365
#
#          date  available  price_y adjusted_price minimum_nights_y  \
# 0  2020-03-14          t  $100.00        $100.00                1
# 1  2020-03-15          t  $100.00        $100.00                1
# 2  2020-03-16          t  $100.00        $100.00                1
# 3  2020-03-17          t  $100.00        $100.00                1
# 4  2020-03-18          t  $100.00        $100.00                1
#
#   maximum_nights booked
# 0            730      0
# 1            730      0
# 2            730      0
# 3            730      0
# 4            730      0
#
# [5 rows x 23 columns]

# %%
# Drop duplicate columns and other columns not relevant to the exploratory analysis
df = df.drop(columns=['name', 'host_name', 'latitude', 'longitude', 'last_review', 'price_y', 
                      'adjusted_price', 'minimum_nights_y'])

# check for na values
df.isnull().any()
# Out:
# listing_id                        False
# host_id                           False
# neighbourhood_group               False
# neighbourhood                     False
# room_type                         False
# price_x                           False
# minimum_nights_x                  False
# number_of_reviews                 False
# reviews_per_month                  True
# calculated_host_listings_count    False
# availability_365                  False
# date                              False
# available                         False
# maximum_nights                    False
# booked                            False
# dtype: bool

# %%
# create new month and year columns from the date column
df['month'] = pd.DatetimeIndex(df['date']).month_name()
df['year'] = pd.DatetimeIndex(df['date']).year

df.head()
# Out:
#    listing_id  host_id neighbourhood_group       neighbourhood     room_type  \
# 0        2060     2259           Manhattan  Washington Heights  Private room
# 1        2060     2259           Manhattan  Washington Heights  Private room
# 2        2060     2259           Manhattan  Washington Heights  Private room
# 3        2060     2259           Manhattan  Washington Heights  Private room
# 4        2060     2259           Manhattan  Washington Heights  Private room
#
#    price_x  minimum_nights_x  number_of_reviews  reviews_per_month  \
# 0      100                 1                  1               0.01
# 1      100                 1                  1               0.01
# 2      100                 1                  1               0.01
# 3      100                 1                  1               0.01
# 4      100                 1                  1               0.01
#
#    calculated_host_listings_count  availability_365        date available  \
# 0                               1               365  2020-03-14         t
# 1                               1               365  2020-03-15         t
# 2                               1               365  2020-03-16         t
# 3                               1               365  2020-03-17         t
# 4                               1               365  2020-03-18         t
#
#    maximum_nights  booked  month  year
# 0             730       0  March  2020
# 1             730       0  March  2020
# 2             730       0  March  2020
# 3             730       0  March  2020
# 4             730       0  March  2020

# %%
# How is listing price affected by location, and type of room
l_r_price = df.groupby(['neighbourhood_group', 'room_type'])['price_x'].mean().unstack()
l_r_price
# Out:
# room_type            Entire home/apt  Hotel room  Private room  Shared room
# neighbourhood_group
# Bronx                     133.637413         NaN     64.260184    81.563636
# Brooklyn                  178.552883  184.206897     76.021201    76.787529
# Manhattan                 247.406252  322.342262    198.091891   101.022727
# Queens                    149.046675  144.297297     69.551412    86.294118
# Staten Island             150.689840         NaN     62.768817    30.200000

# %%
# fill missing values with 0
l_r_price = l_r_price.fillna(0)

# %%
# bar plot showing how the average listing price varies from borough to borough
l_r_price.plot.bar();
plt.title("Average Listing Price by Room Type and Location");

# %%
# calculate number of reservations by month and neighbourhood
new_order = ['January', 'February', 'March', 'April', 'May', 'June', 
             'July', 'August', 'September', 'October', 'November', 'December']

total_booking = df.groupby(['month', 'neighbourhood_group'])['booked'].sum().unstack().reindex(new_order, axis=0)

# bar plot showing how the average listing price varies from borough to borough
total_booking.plot(kind='line');
plt.title("Number of Reservations by Month and Location");

# %%
# How is the number of reservations affected by location, and type of room
reserv = df.groupby(['room_type','neighbourhood_group'])['booked'].sum().unstack()

# fill missing values with 0
reserv = reserv.fillna(0)

# bar plot showing how the average listing price varies from borough to borough
reserv.plot.bar();
plt.title("Number of Reservations by Type of Room and Location");
